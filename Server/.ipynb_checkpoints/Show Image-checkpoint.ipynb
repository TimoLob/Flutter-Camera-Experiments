# %%
from PIL import Image
import pickle

# %%
data = pickle.load(open("out.pkl","rb"))

# %%
print(data)
# Out:
# b'prsqqtsur\x16\x0e\x11\x14\x16\x16\x14\x12\x10\x0e\x0f\x0f\x12\x12\x11\x12\x13\x18!\x19\x19\x10\x0e\x16+64\x17\n\n\t\t 1.10-+**(JTXVYXSSUY\\ZWWY[YY[^`addedimkopnnnsvx{yzzzvw{z~}|}}y}~}|z{{{xwy{xyvtZ(,./1015997=;8;<:6;>:<<>BBDJMORRURQPMKFB\x06\x08\x0b\x0c\x0f\x0f\r\x0c\x0c\x0e\x13\x15!%$\x1b\x17\x12\x0e\x0c\x11\x10\x0c\x0c\t\x06\x07\x08\t\n\x0c\x0b\x0b\x0b\x0c\x0b\x0c\n\x0c\n\t\t\t\t\t\x0b\x0e\x0e\x15\x0b\x0b\x0b\x0b\r\x0b\n\x0b\x0b\r\x0c\x0c\r\t\n\t\t\n\n\t\x07\n\n\x0b\x0b\x0c\r\n\x0c\x0c\x0c\x0c"\xd4\x96\x94\x95\x96\x95\x97\x98\x97\x97\x98\x98\x98\x98\x98\x9a\x9b\x9b\x9b\x9b\x9c\x9c\x9c\x9c\x9c\x9d\x9c\x9d\xa1\xa3\xa3\xa2\xa3\xa5\xa7\xa6\xa6\xa6\xa7\xa7\xa7\xa9\xa9\xab\xac\xad\xa
# ...

# %%
type(data)
len(data)
# Out:
# 76800

# %%
img = Image.frombytes("L",(320,240),data)

# %%
from matplotlib.pyplot import imshow
# %matplotlib inline

import numpy as np

# %%
imshow(np.asarray(img))
